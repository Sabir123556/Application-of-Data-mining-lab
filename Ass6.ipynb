# %% [markdown]
# <a href="https://colab.research.google.com/github/Sabir123556/Application-of-Data-mining-lab/blob/main/Ass6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

data = {
    'Employee_ids': [101, 102, 103, 104, 105],
    'Genders': ['M', 'F', 'M', 'T', 'M'],
    'age': [24, 20, 40, 30, 27]
}
df = pd.DataFrame(data)
label_encoder = LabelEncoder()
df['Gender_Encoded'] = label_encoder.fit_transform(df['Genders'])

one_hot_encoded = pd.get_dummies(df['Genders'], prefix='Genders',dtype=int)
df = pd.concat([df, one_hot_encoded], axis=1)
display(df)
from datetime import datetime

data = {'Name': ['sabir', 'sai','trishala'], 'join year': ['2024', '2023','2022']}
df = pd.DataFrame(data)

df['join year'] = pd.to_datetime(df['join year'])

current_year = datetime.now().year
df['current year'] = current_year - df['join year'].dt.year
display(df)
from datetime import datetime

data = {'Name': ['sabir', 'sai','trishala'], 'join year': ['2024', '2023','2022']}
df = pd.DataFrame(data)

df['join year'] = pd.to_datetime(df['join year'])

current_year = datetime.now().year
df['current year'] = current_year - df['join year'].dt.year
display(df)
data = {'Category': ['A', 'A', 'B', 'B', 'C'], 'Value': [10, 20, 10, 30, 40]}
df = pd.DataFrame(data)

grouped = df.groupby('Category').agg({'Value': ['sum', 'mean']})
display( grouped)

pivot = df.pivot_table(index='Category', values='Value', aggfunc=['sum', 'mean'])
display( pivot)
# Out:
#    Employee_ids Genders  age  Gender_Encoded  Genders_F  Genders_M  Genders_T
# 0           101       M   24               1          0          1          0
# 1           102       F   20               0          1          0          0
# 2           103       M   40               1          0          1          0
# 3           104       T   30               2          0          0          1
# 4           105       M   27               1          0          1          0
#        Name  join year  current year
# 0     sabir 2024-01-01             1
# 1       sai 2023-01-01             2
# 2  trishala 2022-01-01             3
#        Name  join year  current year
# 0     sabir 2024-01-01             1
# 1       sai 2023-01-01             2
# 2  trishala 2022-01-01             3
#          Value
#            sum  mean
# Category
# A           30  15.0
# B           40  20.0
# C           40  40.0
#            sum  mean
#          Value Value
# Category
# A           30  15.0
# ...
